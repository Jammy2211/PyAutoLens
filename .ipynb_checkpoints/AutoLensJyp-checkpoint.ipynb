# %%
# %matplotlib inline

# %%
from pylab import *

# %%
figure()
plot(x, y, 'r')
xlabel('x')
ylabel('y')
title('title')
show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-f8759b5bca28> in <module>()
#       1 figure()
# ----> 2 plot(x, y, 'r')
#       3 xlabel('x')
#       4 ylabel('y')
#       5 title('title')
#
# NameError: name 'x' is not defined
