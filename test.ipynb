# %%
from Image import ImageClass
import matplotlib.pyplot as plt

# %%
% matplotlib inline

# %%
workdir = '/home/jammy/PycharmProjects/AutoLens/'
file = workdir + 'Data/slacs_1_post.fits'

image = ImageClass.Image(file=file, pixel_scale=0.05)
image.load_fits()
# Out:
# Filename: /home/jammy/PycharmProjects/AutoLens/Data/slacs_1_post.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       7   ()
#   1                1 ImageHDU         7   (301, 301)   float32
#   2                1 ImageHDU         7   (301, 301)   float32
#   3                1 ImageHDU         7   (301, 301)   float32

# %%
xdim_arc = image.xdim_arc
ydim_arc = image.ydim_arc

imgplot = plt.imshow(image.data, cmap='hot', extent=[-xdim_arc/2, xdim_arc/2, -ydim_arc/2, ydim_arc/2])
plt.colorbar()
plt.title('Image'), plt.xlabel('Arc Seconds'), plt.ylabel('Arc Seconds')
# Out:
# (<matplotlib.text.Text at 0x7fd057d08c88>,
# ...
#  <matplotlib.text.Text at 0x7fd057ced8d0>)
