# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
    
from LensData.FitsTools import load_fits
from LensData.ArrayTools import *
from LensData.VisualTools import plot_image
import matplotlib.pyplot as plt

image = load_fits(file='/home/jammy/PycharmProjects/AutoLens/Input_Data/slacs_3_post.fits', hdu=1)

image = image[60:240,60:240]

xdim, ydim = get_dimensions(image)
print(xdim, ydim)

plt.imshow(image, clim=(0.0, 0.7))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 180 180

# %%
x, y = np.mgrid[-1:1:180j, -1:1:180j]
print(x)
# Out:
# [[-1.         -1.         -1.         ..., -1.         -1.         -1.        ]
#  [-0.98882682 -0.98882682 -0.98882682 ..., -0.98882682 -0.98882682
#   -0.98882682]
#  [-0.97765363 -0.97765363 -0.97765363 ..., -0.97765363 -0.97765363
#   -0.97765363]
#  ...,
#  [ 0.97765363  0.97765363  0.97765363 ...,  0.97765363  0.97765363
#    0.97765363]
#  [ 0.98882682  0.98882682  0.98882682 ...,  0.98882682  0.98882682
#    0.98882682]
#  [ 1.          1.          1.         ...,  1.          1.          1.        ]]

# %%
class DataObj(object):
    
    def __init__(self):
        return
    
    @classmethod
    def for_setup(cls, image_file, image_hdu, psf_file, psf_hdu, noise_file, noise_hdu, exposure_file, exposure_hdu):        
        return DataObj.__init__(image_file, image_hdu, psf_file, psf_hdu, noise_file, noise_hdu, exposure_file, exposure_hdu)
    
    @classmethod for_analysis(cls)
        return
        
        
class Image(object):
    
    def __init__(self, file_name, hdu):
        Data.Image = self

    def setup_1d(self, Mask, PSF):        
        return
    
Image1 = Image(file_name='lol', hdu=1)
PSF1 = PSF(file_name='sds', hdu=2)
Noise1 = Noise(file_name='sdsas', hdu=3)

DataObj1 = Data(Image1, PSF1, Noise1)
DataObj2 = Data(Imag2, PSF2, Noise2)


def Recon_Adaptive(Data, Settings):

    Model.reset_params()

    Model.defl_xy, Model.defl_xy_sub = Recon.calc_defl_angles(DataObject, Settings)
    Model.src_xy,  Model.src_xy_sub  = Recon.map_image_to_source(DataObject, ModelObject, Settings)
    Model.src_pixel_index            = Recon.pixelize_source_plane(DataObject, ModelObject, Settings)        
    Model.plot_source_plane()

def Recon_MultiWavelength_Adaptive(DataMain, Data_Rest, Settings):
    
    Model.reset_params()

    Model.defl_xy, Model.defl_xy_sub = Recon.calc_defl_angles(DataObject, Settings)

        
if interp == False:
            
    defl_xy_sub = get_defl_angles(image_xy_sub)
    
elif interp == True:
    
    defl_xy_boarder = get_defl_angles(image_xy_boarder)
    defl_xy_sub = interp_defl_angles(image_xy=image_xy, image_xy_boarder = image_xy_boarder)
    

ModelObject.



xdefl, ydefl = calc_defl_angles(xlist, ylist, xlistsub, ylistsub, interp=True)
xsrc, ysrc = map_image_to_source(boarder_move=True)

# %%
import numpy as np

xy_cen1 = [0,1,2]
xy_cen2 = [0,1,2]

print(list(map(lambda l,m : np.sqrt((l**2) + (m**2)), xy_cen1, xy_cen2 )))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-101-1f1ee9aeb3af> in <module>()
#       1 import numpy as np
#       2
# ----> 3 xy_cen1 = [0,1,2][0,1,2]
#       4 xy_cen2 = [0,1,2][0,1,2]
#       5
#
# TypeError: list indices must be integers or slices, not tuple
